# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
import re
import nltk
from nltk.util import pr
stemmer=nltk.SnowballStemmer("english")
from nltk.corpus import stopwords
import string
stopword=set(stopwords.words("english"))

# %%
df=pd.read_csv("twitter.csv")
df
# Out:
#        count  hate_speech_count  offensive_language_count  neither_count  \
# 0          3                  0                         0              3
# 1          3                  0                         3              0
# 2          3                  0                         3              0
# 3          3                  0                         2              1
# 4          6                  0                         6              0
# ...      ...                ...                       ...            ...
# 24778      3                  0                         2              1
# 24779      3                  0                         1              2
# 24780      3                  0                         3              0
# 24781      6                  0                         6              0
# 24782      3                  0                         0              3
#
#        label                                              tweet
# ...

# %%
df

# %%
df=df[['tweet','label']]
df
# Out:
#                                                    tweet  label
# 0      !!! RT @mayasolovely: As a woman you shouldn't...      2
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...      1
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...      1
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...      1
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...      1
# ...                                                  ...    ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...      1
# 24779  you've gone and broke the wrong heart baby, an...      2
# 24780  young buck wanna eat!!.. dat nigguh like I ain...      1
# 24781              youu got wild bitches tellin you lies      1
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...      2
#
# [24783 rows x 2 columns]

# %%
def clean(text):
    text=str(text).lower()
    text=re.sub('\[.*?\]','',text)
    text=re.sub('https?//\s+\www\.\s+','',text)
    text=re.sub('<.*?>+','',text)
    text=re.sub('[%s]' % re.escape(string.punctuation),'',text)
    text=re.sub('\w*\d\w','',text)
    text=[word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text=[stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text
df['tweet']=df["tweet"].apply(clean)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\rohit\AppData\Local\Temp\ipykernel_1784\677720929.py:3: SyntaxWarning: invalid escape sequence '\['
#   text=re.sub('\[.*?\]','',text)
# C:\Users\rohit\AppData\Local\Temp\ipykernel_1784\677720929.py:4: SyntaxWarning: invalid escape sequence '\s'
#   text=re.sub('https?//\s+\www\.\s+','',text)
# C:\Users\rohit\AppData\Local\Temp\ipykernel_1784\677720929.py:7: SyntaxWarning: invalid escape sequence '\w'
#   text=re.sub('\w*\d\w','',text)
# C:\Users\rohit\AppData\Local\Temp\ipykernel_1784\677720929.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df
# Out:
#                                                    tweet  label
# 0       rt mayasolov woman shouldnt complain clean ho...      2
# 1       rt  boy dat coldtyga dwn bad cuffin dat hoe p...      1
# 2       rt urkindofbrand dawg rt ife ever fuck bitch ...      1
# 3                 rt cganderson vivabas look like tranni      1
# 4       rt shenikarobert shit hear might true might f...      1
# ...                                                  ...    ...
# 24778  yous muthafin lie ifeask earl coreyemanuel rig...      1
# 24779  youv gone broke wrong heart babi drove redneck...      2
# 24780  young buck wanna eat dat nigguh like aint fuck...      1
# 24781                     youu got wild bitch tellin lie      1
# 24782  ruffl  ntac eileen dahlia  beauti color combin...      2
#
# [24783 rows x 2 columns]

# %%
x=np.array(df["tweet"])
y=np.array(df["label"])
cv=CountVectorizer()
x=cv.fit_transform(x)
x_train,x_text,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
DT=DecisionTreeClassifier()

# %%
DT.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Step 4 - Making Predictions and evaluations

ytrainPred = model_1.predict(xtrain)

train_accuracy = (ytrain == ytrainPred).sum()/len(xtrain)
print(train_accuracy)

print()

ytestPred = model_1.predict(xtest)

test_accuracy = (ytest == ytestPred).sum()/len(xtest)
print(test_accuracy)

# %%
test_data="i don't like you"
df=cv.transform([test_data]).toarray()
df
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)
